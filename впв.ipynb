# %% [markdown]
# ## Скорость испарения капель воды и спирта в зависимости от температуры и площади поверхности испарения.
#
# **Цель работы:** уставить зависимость скорости испарения жидкости от площади поверхности и температуры поверхности, на которой находится жидкость.
#
# **В работе использовались:**  шприц, поверхность с измерительной шкалой, фен (поток теплого воздуха), секундомер, вода, спирт.
#
# ### Теория
# Процесс парообразования со свободной поверхности жидкости на зывается испарением. Для выхода из жидкости молекулы должны преодолеть силы притяжения со стороны соседних молекул, то есть совершить работу против этих сил. Кроме того, должна быть совер шена работа против внешнего давления, равная $A=p∆v$, где $∆v = v_п −v_ж$. Вся эта работа совершается за счет кинетической энергии тепло вого движения молекул, поэтому покинуть жидкость могут не все молекулы, а лишь обладающие достаточной кинетической энергией.
#
# Процесс испарения той или иной жидкости характеризуется вели чиной скорости испарения, которая численно равна массе жидкости, испаряющейся с единицы площади свободной поверхности в единицу времени:
# $$W_e = \frac{1}{S} \frac{dm}{d\tau}, \: S = 4πR^2$$
#
# где $S = 4πR^2$ — площадь поверхности капли при допущении ее сферической формы. В процессе нагрева капли ее радиус $R$ изменяется от начального значения $𝑅_0$ до конечного значения $𝑅^*$ за фиксированное время $\tau$. Масса капель также меняется от значения $𝑚_0$ до значения $𝑚^*$ (нас будет интересовать $m^* = 0$.
#
# Запишем выражение для объема капли и ее массы:
# $$𝑉 = \frac{4}{3}𝜋𝑅^3, \: m = \rho V $$
# Тогда скорость испарения жидкости вычисляется как:
# $$W_ed \int_0^\tau \tau = \frac{1}{S} \int_{m_0}^0dm$$
# $$W_e \tau = \frac{1}{S} m_0 = \frac{1}{4\pi R^2} \rho \frac{4}{3}\pi R^3$$
# $$W_e = \frac{1}{3} \frac{1}{\tau} \rho R$$
#
# ### Ход работы
# Помещаем по одной капле спирта и воды на поверхность с измерительной шкалой, запускаем секундомер и ждем изменения радиуса капли с течением времени. Проводим измерения при комнатной температуре без потока теплого воздуха, после этого включаем поток теплого воздуха и фиксируем изменения радиуса в зависимости от времени.
#
# Контролировать температуру теплого воздуха я буду изменением расстояния от капли до непосредственно фена (поскольку измерение температуры будет проводиться возле капли, то от этого расстояния не будет ничего зависеть для нашего опыта, ведь зависимость уже включена в температуру), замерять температуру буду с помощью термометра.
#
# 1. **Исследуем изменения радиуса капли в зависимости от времени $\tau$ при испарении без нагрева для воды и спирта:**
#
# Данные:
# - $\rho_{воды} = 1000 кг/м^3$
# - $\rho_{спирта} = 789,3 кг/м^3$
# - $T_{комн} = 24°C$
# - $R_0 = 5 мм$

# %%
import numpy as np
import pandas as pd
from pandas.api.types import is_numeric_dtype

import matplotlib.pyplot as plt
import seaborn as sns

data1 = pd.read_csv('data1.csv')
data1
# Out:
#    t, мин  ΔR (вода), мм  ΔR (спирт), мм
# 0    5.00           0.50            1.00
# 1    7.42           1.00            2.10
# 2    8.15           1.07            2.40
# 3    9.32           1.23            2.96
# 4   10.45           1.45            3.65
# 5   11.13           1.55            4.13
# 6   12.02           1.78            5.00

# %% [markdown]
# ![image.png](attachment:ee305445-5e0b-41c8-b9aa-7c82f8b56cb9.png)
#
# 2. **Теперь проведем опыт установления зависимости скорости испарения от времени, рассматривая разные площади капель спирта и воды. Будем фиксировать изменение на один миллиметр каждого из радиусов вышеуказанных. Проведем измерения для разных температур.**
#
# - T1 = 38 °C = 311 К
# ![image.png](attachment:f1f7b5d9-48a7-45b5-99fc-f3e88dcec0f5.png)
# ![image.png](attachment:cc6dd486-8565-4543-9621-4ac63f2c2ab4.png)
#
# - T2 = 50 °C = 323 К
# ![image.png](attachment:e9ecf14d-4027-4942-be37-b10a39a44dfe.png)
# ![image.png](attachment:ec3b72f8-21f9-4a0c-a2a7-1f6b48d63ec0.png)

# %% [markdown]
# По графику 2 видно, что коэффициенты наклона при изменении температуры поверхности стали больше, следовательно скорость испарения жидкости зависит и от подаваемой теплоты.
#
# ### Вывод
# В работе было установлена зависимость скорости испарения жидкости от температуры поверхности и размера самой капли. Почему для испарения жидкости
# требуется затрата тепла? Это можно понять с молекулярной точки зрения. Скорости молекул жидкости распределены по Максвеллу. Вылететь из жидкости в
# окружающее пространство могут только наиболее быстрые молекулы, так как лишь они в состоянии преодолеть силы притяжения, действующие в поверхностном слое жидкости. Проходя через поверхностный слой, так что температура пара оказывается равной температуре жидкости. В результате ухода быстрых молекул жидкость охлаждается. Следовательно, для поддержания ее температуры постоянной требуется подвод тепла. В таком случае чем выше подводимая теплота, тем выше интенсивность испарения, что и показал эксперимент.
#
# Из эксперимента мы получили также прямую зависимость скорости испарения от площади поверхности, я думаю, что эта зависимость следует из
# молекулярной структуры: больше площадь => больше молекул в поверхностном слое => больше шанс вылететь из капли.
#
# Также в работе было экспериментальным методом установлена зависимость скорости испарения от рода жидкости: спирт испаряется быстрее чем вода, так как его молекулы обладают большей кинетической энергией и меньшим молекулярным притяжением.
